# %% [markdown]
# ## Replicating & Copying Parameters for GPT

# %%
import torch as t
from torch import nn
from torch.utils.data import Dataset, DataLoader
import plotly.express as px
from IPython.display import display
import pandas as pd
import numpy as np
import transformers
from fancy_einsum import einsum
from dataclasses import dataclass
from tqdm.notebook import tqdm_notebook
import matplotlib

from einops import rearrange, reduce, repeat

# %%
import sys 
sys.path.append('../common')

import gpt_modules as gpt
import utils

# %%
from transformer_modules import Dropout, LayerNorm, MLP, TransformerConfig, Embedding
from general_modules import Linear

# %%
class GPTAttention(nn.Module):
    W_QKV: nn.Linear
    W_O: nn.Linear

    def __init__(self, hidden_size: int, num_heads: int, dropout: float):
        super().__init__()
        self.num_heads = num_heads
        self.query_size = int(hidden_size / num_heads)
        
        self.qkv = Linear(hidden_size, 3 * hidden_size)
        self.ff = Linear(hidden_size, hidden_size)

        self.dropout1 = Dropout(p=dropout)
        self.dropout2 = Dropout(p=dropout)

    def multihead_masked_attention(
        self, Q: t.Tensor, K: t.Tensor, V: t.Tensor, num_heads: int
    ):
        """
        Implements multihead masked attention on the matrices Q, K and V.

        Q: shape (batch, seq, nheads*headsize)
        K: shape (batch, seq, nheads*headsize)
        V: shape (batch, seq, nheads*headsize)

        returns: shape (batch, seq, nheads*headsize)
        """
        Q = rearrange(
            Q, "B S (nheads headsize) -> B S nheads headsize", nheads=num_heads
        )
        K = rearrange(
            K, "B S (nheads headsize) -> B S nheads headsize", nheads=num_heads
        )
        V = rearrange(
            V, "B S (nheads headsize) -> B S nheads headsize", nheads=num_heads
        )

        batch_size, seq_len, nheads, headsize = Q.shape
        scores = einsum(
            "B Qseq nheads headsize, B Kseq nheads headsize -> B nheads Qseq Kseq", Q, K
        )
        scores /= Q.shape[-1] ** 0.5

        # create lower-left triangle of ones, including the diagonal
        mask = t.tril(t.ones(seq_len, seq_len).to(Q.device), diagonal=0)
        # mask out the upper-right triangle
        scores = scores.masked_fill(mask == 0, -1e9)

        scores = t.softmax(scores, dim=-1)

        scores = self.dropout1(scores)

        Z = einsum(
            "B nheads Qseq Kseq, B Kseq nheads headsize -> B Qseq nheads headsize",
            scores,
            V,
        )
        Z = rearrange(Z, "B Qseq nheads headsize -> B Qseq (nheads headsize)")
        return Z

    def forward(self, x: t.Tensor) -> t.Tensor:
        """
        x: shape (batch, seq, hidden_size)

        Return: shape (batch, seq, hidden_size)
        """
        out = self.qkv(x)
        Q, K, V = t.tensor_split(out, 3, dim=-1)

        Z = self.multihead_masked_attention(Q, K, V, self.num_heads)
        out = self.ff(Z)
        out = self.dropout2(out)
        return out

# %%
class GPTDecoder(nn.Module):

    def __init__(self, config: TransformerConfig):
        super().__init__()
        self.lnorm1 = LayerNorm(config.hidden_size, eps=config.layer_norm_epsilon)
        self.attn = GPTAttention(config.hidden_size, config.num_heads, config.dropout)
        self.lnorm2 = LayerNorm(config.hidden_size, eps=config.layer_norm_epsilon)
        self.mlp = MLP(config.hidden_size, config.dropout)

    def forward(self, x: t.Tensor) -> t.Tensor:
        attn = self.attn(self.lnorm1(x))
        out = attn + x
        mlp = self.mlp(self.lnorm2(out))
        out = mlp + out
        return out

# %%
class GPT(nn.Module):

    def __init__(self, config: TransformerConfig):
        super().__init__()
        self.emb = Embedding(config.vocab_size, config.hidden_size)
        self.pos_emb = Embedding(config.max_seq_len, config.hidden_size)
        self.dropout = Dropout(p=config.dropout)

        decoders = [GPTDecoder(config) for l in range(config.num_layers)]
        self.decoders = nn.Sequential(*decoders)
        
        self.post_norm = LayerNorm(config.hidden_size)

    def forward(self, x: t.Tensor) -> t.Tensor:
        pos = t.arange(x.shape[1], device=x.device)
        embedding = self.emb(x) + self.pos_emb(pos)
        embedding = self.dropout(embedding)

        out = self.decoders(embedding)
        out = self.post_norm(out)

        out = einsum("B S E, V E -> B S V", out, self.emb.weight)

        return out

# %%
config = TransformerConfig(
    num_layers = 12,
    num_heads = 12,
    vocab_size = 50257,
    hidden_size = 768,
    max_seq_len = 1024,
    dropout = 0.1,
    layer_norm_epsilon = 1e-05
)

# %%
my_gpt = GPT(config).train()
gpt = transformers.AutoModelForCausalLM.from_pretrained("gpt2").train()

# compare the number of parameters between my implementation and the original
utils.print_param_count(my_gpt, gpt)
# Out:
# Model 1, total params = 124439808
#                              name_1       shape_1  num_params_1
# 0                        emb.weight  (50257, 768)      38597376
# 1                    pos_emb.weight   (1024, 768)        786432
# 2          decoders.0.lnorm1.weight        (768,)           768
# 3            decoders.0.lnorm1.bias        (768,)           768
# 4        decoders.0.attn.qkv.weight   (2304, 768)       1769472
# ..                              ...           ...           ...
# 143    decoders.11.mlp.linear1.bias       (3072,)          3072
# 144  decoders.11.mlp.linear2.weight   (768, 3072)       2359296
# 145    decoders.11.mlp.linear2.bias        (768,)           768
# 146                post_norm.weight        (768,)           768
# 147                  post_norm.bias        (768,)           768
#
# [148 rows x 3 columns]
# Model 2, total params = 124439808
#      num_params_2       shape_2                              name_2
# 0        38597376  (50257, 768)              transformer.wte.weight
# 1          786432   (1024, 768)              transformer.wpe.weight
# 2             768        (768,)         transformer.h.0.ln_1.weight
# 3             768        (768,)           transformer.h.0.ln_1.bias
# 4         1769472   (768, 2304)  transformer.h.0.attn.c_attn.weight
# ..            ...           ...                                 ...
# 143          3072       (3072,)      transformer.h.11.mlp.c_fc.bias
# 144       2359296   (3072, 768)  transformer.h.11.mlp.c_proj.weight
# 145           768        (768,)    transformer.h.11.mlp.c_proj.bias
# 146           768        (768,)             transformer.ln_f.weight
# 147           768        (768,)               transformer.ln_f.bias
#
# [148 rows x 3 columns]
# All parameter counts match!
# <style type="text/css">
# #T_5f54d_row0_col2, #T_5f54d_row0_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_5f54d_row1_col2, #T_5f54d_row1_col3 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_5f54d_row2_col2, #T_5f54d_row2_col3, #T_5f54d_row3_col2, #T_5f54d_row3_col3, #T_5f54d_row7_col2, #T_5f54d_row7_col3, #T_5f54d_row8_col2, #T_5f54d_row8_col3, #T_5f54d_row9_col2, #T_5f54d_row9_col3, #T_5f54d_row13_col2, #T_5f54d_row13_col3, #T_5f54d_row14_col2, #T_5f54d_row14_col3, #T_5f54d_row15_col2, #T_5f54d_row15_col3, #T_5f54d_row19_col2, #T_5f54d_row19_col3, #T_5f54d_row20_col2, #T_5f54d_row20_col3, #T_5f54d_row21_col2, #T_5f54d_row21_col3, #T_5f54d_row25_col2, #T_5f54d_row25_col3, #T_5f54d_row26_col2, #T_5f54d_row26_col3, #T_5f54d_row27_col2, #T_5f54d_row27_col3, #T_5f54d_row31_col2, #T_5f54d_row31_col3, #T_5f54d_row32_col2, #T_5f54d_row32_col3, #T_5f54d_row33_col2, #T_5f54d_row33_col3, #T_5f54d_row37_col2, #T_5f54d_row37_col3, #T_5f54d_row38_col2, #T_5f54d_row38_col3, #T_5f54d_row39_col2, #T_5f54d_row39_col3, #T_5f54d_row43_col2, #T_5f54d_row43_col3, #T_5f54d_row44_col2, #T_5f54d_row44_col3, #T_5f54d_row45_col2, #T_5f54d_row45_col3, #T_5f54d_row49_col2, #T_5f54d_row49_col3, #T_5f54d_row50_col2, #T_5f54d_row50_col3, #T_5f54d_row51_col2, #T_5f54d_row51_col3, #T_5f54d_row55_col2, #T_5f54d_row55_col3, #T_5f54d_row56_col2, #T_5f54d_row56_col3, #T_5f54d_row57_col2, #T_5f54d_row57_col3, #T_5f54d_row61_col2, #T_5f54d_row61_col3, #T_5f54d_row62_col2, #T_5f54d_row62_col3, #T_5f54d_row63_col2, #T_5f54d_row63_col3, #T_5f54d_row67_col2, #T_5f54d_row67_col3, #T_5f54d_row68_col2, #T_5f54d_row68_col3, #T_5f54d_row69_col2, #T_5f54d_row69_col3, #T_5f54d_row73_col2, #T_5f54d_row73_col3, #T_5f54d_row74_col2, #T_5f54d_row74_col3, #T_5f54d_row75_col2, #T_5f54d_row75_col3, #T_5f54d_row79_col2, #T_5f54d_row79_col3, #T_5f54d_row80_col2, #T_5f54d_row80_col3, #T_5f54d_row81_col2, #T_5f54d_row81_col3, #T_5f54d_row85_col2, #T_5f54d_row85_col3, #T_5f54d_row86_col2, #T_5f54d_row86_col3, #T_5f54d_row87_col2, #T_5f54d_row87_col3, #T_5f54d_row91_col2, #T_5f54d_row91_col3, #T_5f54d_row92_col2, #T_5f54d_row92_col3, #T_5f54d_row93_col2, #T_5f54d_row93_col3, #T_5f54d_row97_col2, #T_5f54d_row97_col3, #T_5f54d_row98_col2, #T_5f54d_row98_col3, #T_5f54d_row99_col2, #T_5f54d_row99_col3, #T_5f54d_row103_col2, #T_5f54d_row103_col3, #T_5f54d_row104_col2, #T_5f54d_row104_col3, #T_5f54d_row105_col2, #T_5f54d_row105_col3, #T_5f54d_row109_col2, #T_5f54d_row109_col3, #T_5f54d_row110_col2, #T_5f54d_row110_col3, #T_5f54d_row111_col2, #T_5f54d_row111_col3, #T_5f54d_row115_col2, #T_5f54d_row115_col3, #T_5f54d_row116_col2, #T_5f54d_row116_col3, #T_5f54d_row117_col2, #T_5f54d_row117_col3, #T_5f54d_row121_col2, #T_5f54d_row121_col3, #T_5f54d_row122_col2, #T_5f54d_row122_col3, #T_5f54d_row123_col2, #T_5f54d_row123_col3, #T_5f54d_row127_col2, #T_5f54d_row127_col3, #T_5f54d_row128_col2, #T_5f54d_row128_col3, #T_5f54d_row129_col2, #T_5f54d_row129_col3, #T_5f54d_row133_col2, #T_5f54d_row133_col3, #T_5f54d_row134_col2, #T_5f54d_row134_col3, #T_5f54d_row135_col2, #T_5f54d_row135_col3, #T_5f54d_row139_col2, #T_5f54d_row139_col3, #T_5f54d_row140_col2, #T_5f54d_row140_col3, #T_5f54d_row141_col2, #T_5f54d_row141_col3, #T_5f54d_row145_col2, #T_5f54d_row145_col3, #T_5f54d_row146_col2, #T_5f54d_row146_col3, #T_5f54d_row147_col2, #T_5f54d_row147_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_5f54d_row4_col2, #T_5f54d_row4_col3, #T_5f54d_row16_col2, #T_5f54d_row16_col3, #T_5f54d_row28_col2, #T_5f54d_row28_col3, #T_5f54d_row40_col2, #T_5f54d_row40_col3, #T_5f54d_row52_col2, #T_5f54d_row52_col3, #T_5f54d_row64_col2, #T_5f54d_row64_col3, #T_5f54d_row76_col2, #T_5f54d_row76_col3, #T_5f54d_row88_col2, #T_5f54d_row88_col3, #T_5f54d_row100_col2, #T_5f54d_row100_col3, #T_5f54d_row112_col2, #T_5f54d_row112_col3, #T_5f54d_row124_col2, #T_5f54d_row124_col3, #T_5f54d_row136_col2, #T_5f54d_row136_col3 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_5f54d_row5_col2, #T_5f54d_row5_col3, #T_5f54d_row17_col2, #T_5f54d_row17_col3, #T_5f54d_row29_col2, #T_5f54d_row29_col3, #T_5f54d_row41_col2, #T_5f54d_row41_col3, #T_5f54d_row53_col2, #T_5f54d_row53_col3, #T_5f54d_row65_col2, #T_5f54d_row65_col3, #T_5f54d_row77_col2, #T_5f54d_row77_col3, #T_5f54d_row89_col2, #T_5f54d_row89_col3, #T_5f54d_row101_col2, #T_5f54d_row101_col3, #T_5f54d_row113_col2, #T_5f54d_row113_col3, #T_5f54d_row125_col2, #T_5f54d_row125_col3, #T_5f54d_row137_col2, #T_5f54d_row137_col3 {
#   background-color: #482475;
#   color: #f1f1f1;
# }
# #T_5f54d_row6_col2, #T_5f54d_row6_col3, #T_5f54d_row18_col2, #T_5f54d_row18_col3, #T_5f54d_row30_col2, #T_5f54d_row30_col3, #T_5f54d_row42_col2, #T_5f54d_row42_col3, #T_5f54d_row54_col2, #T_5f54d_row54_col3, #T_5f54d_row66_col2, #T_5f54d_row66_col3, #T_5f54d_row78_col2, #T_5f54d_row78_col3, #T_5f54d_row90_col2, #T_5f54d_row90_col3, #T_5f54d_row102_col2, #T_5f54d_row102_col3, #T_5f54d_row114_col2, #T_5f54d_row114_col3, #T_5f54d_row126_col2, #T_5f54d_row126_col3, #T_5f54d_row138_col2, #T_5f54d_row138_col3 {
#   background-color: #25ac82;
#   color: #f1f1f1;
# }
# #T_5f54d_row10_col2, #T_5f54d_row10_col3, #T_5f54d_row12_col2, #T_5f54d_row12_col3, #T_5f54d_row22_col2, #T_5f54d_row22_col3, #T_5f54d_row24_col2, #T_5f54d_row24_col3, #T_5f54d_row34_col2, #T_5f54d_row34_col3, #T_5f54d_row36_col2, #T_5f54d_row36_col3, #T_5f54d_row46_col2, #T_5f54d_row46_col3, #T_5f54d_row48_col2, #T_5f54d_row48_col3, #T_5f54d_row58_col2, #T_5f54d_row58_col3, #T_5f54d_row60_col2, #T_5f54d_row60_col3, #T_5f54d_row70_col2, #T_5f54d_row70_col3, #T_5f54d_row72_col2, #T_5f54d_row72_col3, #T_5f54d_row82_col2, #T_5f54d_row82_col3, #T_5f54d_row84_col2, #T_5f54d_row84_col3, #T_5f54d_row94_col2, #T_5f54d_row94_col3, #T_5f54d_row96_col2, #T_5f54d_row96_col3, #T_5f54d_row106_col2, #T_5f54d_row106_col3, #T_5f54d_row108_col2, #T_5f54d_row108_col3, #T_5f54d_row118_col2, #T_5f54d_row118_col3, #T_5f54d_row120_col2, #T_5f54d_row120_col3, #T_5f54d_row130_col2, #T_5f54d_row130_col3, #T_5f54d_row132_col2, #T_5f54d_row132_col3, #T_5f54d_row142_col2, #T_5f54d_row142_col3, #T_5f54d_row144_col2, #T_5f54d_row144_col3 {
#   background-color: #58c765;
#   color: #000000;
# }
# #T_5f54d_row11_col2, #T_5f54d_row11_col3, #T_5f54d_row23_col2, #T_5f54d_row23_col3, #T_5f54d_row35_col2, #T_5f54d_row35_col3, #T_5f54d_row47_col2, #T_5f54d_row47_col3, #T_5f54d_row59_col2, #T_5f54d_row59_col3, #T_5f54d_row71_col2, #T_5f54d_row71_col3, #T_5f54d_row83_col2, #T_5f54d_row83_col3, #T_5f54d_row95_col2, #T_5f54d_row95_col3, #T_5f54d_row107_col2, #T_5f54d_row107_col3, #T_5f54d_row119_col2, #T_5f54d_row119_col3, #T_5f54d_row131_col2, #T_5f54d_row131_col3, #T_5f54d_row143_col2, #T_5f54d_row143_col3 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5f54d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f54d_level0_col0" class="col_heading level0 col0" >name_1</th>
#       <th id="T_5f54d_level0_col1" class="col_heading level0 col1" >shape_1</th>
#       <th id="T_5f54d_level0_col2" class="col_heading level0 col2" >num_params_1</th>
#       <th id="T_5f54d_level0_col3" class="col_heading level0 col3" >num_params_2</th>
#       <th id="T_5f54d_level0_col4" class="col_heading level0 col4" >shape_2</th>
#       <th id="T_5f54d_level0_col5" class="col_heading level0 col5" >name_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f54d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f54d_row0_col0" class="data row0 col0" >emb.weight</td>
#       <td id="T_5f54d_row0_col1" class="data row0 col1" >(50257, 768)</td>
#       <td id="T_5f54d_row0_col2" class="data row0 col2" >38597376</td>
#       <td id="T_5f54d_row0_col3" class="data row0 col3" >38597376</td>
#       <td id="T_5f54d_row0_col4" class="data row0 col4" >(50257, 768)</td>
#       <td id="T_5f54d_row0_col5" class="data row0 col5" >transformer.wte.weight</td>
#     </tr>
#     <tr>
#       <th id="T_5f54d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5f54d_row1_col0" class

# %%
def copy_weights_from_gpt(my_gpt: GPT, gpt) -> GPT:
    '''
    Copy over the weights from pretrained GPT to this implementation of gpt.
    '''
    mydict = dict(my_gpt.named_parameters())
    pretraineddict = dict(gpt.named_parameters())

    # Initialize an empty dictionary to store the correct key-value pairs
    state_dict_to_load = {}

    for (my_name, my_param), (pt_name, pt_param) in zip(mydict.items(), pretraineddict.items()):
        if len(my_param.shape)==2 and my_param.shape == pt_param.T.shape:
            pt_param = pt_param.T

        state_dict_to_load[my_name] = pt_param

    my_gpt.load_state_dict(state_dict_to_load)
    
    return my_gpt

# %%
copy_weights_from_gpt(my_gpt, gpt)
# Out:
# GPT(
#   (emb): Embedding(50257, 768)
#   (pos_emb): Embedding(1024, 768)
#   (dropout): Dropout(p=0.1)
#   (decoders): Sequential(
#     (0): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (1): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (2): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (3): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (4): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (5): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (6): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (7): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (8): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (9): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (10): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#     (11): GPTDecoder(
#       (lnorm1): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (attn): GPTAttention(
#         (qkv): Linear()
#         (ff): Linear()
#         (dropout1): Dropout(p=0.1)
#         (dropout2): Dropout(p=0.1)
#       )
#       (lnorm2): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
#       (mlp): MLP(
#         (linear1): Linear()
#         (gelu): GELU()
#         (linear2): Linear()
#         (dropout): Dropout(p=0.1)
#       )
#     )
#   )
#   (post_norm): LayerNorm(normalized_shape=(768,), eps=1e-05, elementwise_affine=True)
# )

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained("gpt2")
utils.test_load_pretrained_weights(my_gpt, tokenizer)
# Out:
# Prompt:  Former President of the United States of America, George
# Your model's top 10 predictions:  [' W', ' H', ' Bush', ' Washington', ' HW', ' Herbert', ' Pat', ' S', ' Soros', ' Wallace']

# %% [markdown]
# ## TODO: Finetuning
